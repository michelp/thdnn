# %%
from dnn import challenge

challenge.run('/home/jovyan/dnn/dnn_data', 1024, 120)
# Out:
# func:dnn.io.load_images took: 0.0253
# func:dnn.io.load_layers took: 0.0143
# func:dnn.io.generate_bias took: 0.1570
# func:dnn.dnn.mad took: 0.4467
# func:dnn.dnn.relu took: 0.1412
# func:dnn.dnn.mad took: 0.4553
# func:dnn.dnn.relu took: 0.1133
# func:dnn.dnn.mad took: 0.2963
# func:dnn.dnn.relu took: 0.0392
# func:dnn.dnn.mad took: 0.2023
# func:dnn.dnn.relu took: 0.0262
# func:dnn.dnn.mad took: 0.1319
# func:dnn.dnn.relu took: 0.0219
# func:dnn.dnn.mad took: 0.1577
# func:dnn.dnn.relu took: 0.1698
# func:dnn.dnn.mad took: 0.2003
# func:dnn.dnn.relu took: 0.0120
# func:dnn.dnn.mad took: 0.0613
# func:dnn.dnn.relu took: 0.0076
# func:dnn.dnn.mad took: 0.0505
# func:dnn.dnn.relu took: 0.0071
# func:dnn.dnn.mad took: 0.0447
# func:dnn.dnn.relu took: 0.0080
# func:dnn.dnn.mad took: 0.0550
# func:dnn.dnn.relu took: 0.0105
# func:dnn.dnn.mad took: 0.0456
# func:dnn.dnn.relu took: 0.0144
# func:dnn.dnn.mad took: 0.0434
# func:dnn.dnn.relu took: 0.0116
# func:dnn.dnn.mad took: 0.0442
# ...
